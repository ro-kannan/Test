# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as plx
import os

# %%
df=pd.read_csv('Car details v3.csv')

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# 2     12.7@ 2,700(kgm@ rpm)    5.0
# 3  22.4 kgm at 1750-2750rpm    5.0
# 4     11.5@ 4,500(kgm@ rpm)    5.0

# %%
df.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
df=df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7906 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7906 non-null   object
#  1   year           7906 non-null   int64
#  2   selling_price  7906 non-null   int64
#  3   km_driven      7906 non-null   int64
#  4   fuel           7906 non-null   object
#  5   seller_type    7906 non-null   object
#  6   transmission   7906 non-null   object
#  7   owner          7906 non-null   object
#  8   mileage        7906 non-null   object
#  9   engine         7906 non-null   object
#  10  max_power      7906 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7906 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 586.8+ KB

# %%
df.describe()
# Out:
#               year  selling_price     km_driven        seats
# count  7906.000000   7.906000e+03  7.906000e+03  7906.000000
# mean   2013.983936   6.498137e+05  6.918866e+04     5.416393
# std       3.863695   8.135827e+05  5.679230e+04     0.959208
# min    1994.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2012.000000   2.700000e+05  3.500000e+04     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.900000e+05  9.542500e+04     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000

# %%
df.dtypes
# Out:
# name              object
# year               int64
# selling_price      int64
# km_driven          int64
# fuel              object
# seller_type       object
# transmission      object
# owner             object
# mileage           object
# engine            object
# max_power         object
# torque            object
# seats            float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7906 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7906 non-null   object
#  1   year           7906 non-null   int64
#  2   selling_price  7906 non-null   int64
#  3   km_driven      7906 non-null   int64
#  4   fuel           7906 non-null   object
#  5   seller_type    7906 non-null   object
#  6   transmission   7906 non-null   object
#  7   owner          7906 non-null   object
#  8   mileage        7906 non-null   object
#  9   engine         7906 non-null   object
#  10  max_power      7906 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7906 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 586.8+ KB

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='object')

# %%
feat = [ 'year', 'fuel', 'seller_type','transmission', 'owner','seats']
df_feat = df[[ 'fuel', 'seller_type','transmission', 'owner','seats']]

# %%
for i in df_feat :
    print(df_feat[i].unique())
# Out:
# ['Diesel' 'Petrol' 'LPG' 'CNG']
# ['Individual' 'Dealer' 'Trustmark Dealer']
# ['Manual' 'Automatic']
# ['First Owner' 'Second Owner' 'Third Owner' 'Fourth & Above Owner'
#  'Test Drive Car']
# [ 5.  4.  7.  8.  6.  9. 10. 14.  2.]

# %%
df.drop(df.index[df['owner']=='Test Drive Car'],inplace=True)

# %%
df[df['owner']=='Test Drive Car']
# Out:
# Empty DataFrame
# Columns: [name, year, selling_price, km_driven, fuel, seller_type, transmission, owner, mileage, engine, max_power, torque, seats]
# Index: []

# %%
print(df_feat['owner'].unique())
# Out:
# ['First Owner' 'Second Owner' 'Third Owner' 'Fourth & Above Owner'
#  'Test Drive Car']

# %%
df.shape
# Out:
# (7901, 13)

# %%
df[['seats']] = df[['seats']].fillna(0.0).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7901 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7901 non-null   object
#  1   year           7901 non-null   int64
#  2   selling_price  7901 non-null   int64
#  3   km_driven      7901 non-null   int64
#  4   fuel           7901 non-null   object
#  5   seller_type    7901 non-null   object
#  6   transmission   7901 non-null   object
#  7   owner          7901 non-null   object
#  8   mileage        7901 non-null   object
#  9   engine         7901 non-null   object
#  10  max_power      7901 non-null   object
#  11  torque         7901 non-null   object
#  12  seats          7901 non-null   int32
# dtypes: int32(1), int64(3), object(9)
# memory usage: 555.5+ KB

# %%
for i in range(len(feat)) :
    plt.figure(figsize=[10,4])
    plt.figure()
    sns.countplot(x=feat[i],data=df)
    plt.show()
    i += 1

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm      5
# 1       250Nm@ 1500-2500rpm      5
# 2     12.7@ 2,700(kgm@ rpm)      5
# 3  22.4 kgm at 1750-2750rpm      5
# 4     11.5@ 4,500(kgm@ rpm)      5

# %%
df['mileage']
# Out:
# 0        23.4 kmpl
# 1       21.14 kmpl
# 2        17.7 kmpl
# 3        23.0 kmpl
# 4        16.1 kmpl
#            ...
# 8123     18.5 kmpl
# 8124     16.8 kmpl
# 8125     19.3 kmpl
# 8126    23.57 kmpl
# 8127    23.57 kmpl
# Name: mileage, Length: 7901, dtype: object

# %%
df['mileage'].dtype
# Out:
# dtype('O')

# %%
df['mileage']=df['mileage'].str.replace(' kmpl','')

# %%
df['mileage']=df['mileage'].str[0:5].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7901 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7901 non-null   object
#  1   year           7901 non-null   int64
#  2   selling_price  7901 non-null   int64
#  3   km_driven      7901 non-null   int64
#  4   fuel           7901 non-null   object
#  5   seller_type    7901 non-null   object
#  6   transmission   7901 non-null   object
#  7   owner          7901 non-null   object
#  8   mileage        7901 non-null   float64
#  9   engine         7901 non-null   object
#  10  max_power      7901 non-null   object
#  11  torque         7901 non-null   object
#  12  seats          7901 non-null   int32
# dtypes: float64(1), int32(1), int64(3), object(8)
# memory usage: 842.4+ KB

# %%
df['engine']=df['engine'].str.replace('CC','').astype(int)

# %%
sns.distplot(df['mileage'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7901 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7901 non-null   object
#  1   year           7901 non-null   int64
#  2   selling_price  7901 non-null   int64
#  3   km_driven      7901 non-null   int64
#  4   fuel           7901 non-null   object
#  5   seller_type    7901 non-null   object
#  6   transmission   7901 non-null   object
#  7   owner          7901 non-null   object
#  8   mileage        7901 non-null   float64
#  9   engine         7901 non-null   int32
#  10  max_power      7901 non-null   object
#  11  torque         7901 non-null   object
#  12  seats          7901 non-null   int32
# dtypes: float64(1), int32(2), int64(3), object(7)
# memory usage: 842.4+ KB

# %%
sns.distplot(df['engine'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7901 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7901 non-null   object
#  1   year           7901 non-null   int64
#  2   selling_price  7901 non-null   int64
#  3   km_driven      7901 non-null   int64
#  4   fuel           7901 non-null   object
#  5   seller_type    7901 non-null   object
#  6   transmission   7901 non-null   object
#  7   owner          7901 non-null   object
#  8   mileage        7901 non-null   float64
#  9   engine         7901 non-null   int32
#  10  max_power      7901 non-null   object
#  11  torque         7901 non-null   object
#  12  seats          7901 non-null   int32
# dtypes: float64(1), int32(2), int64(3), object(7)
# memory usage: 842.4+ KB

# %%
df['no_years'] = 2021

# %%
df['no_years'] = 2021 - df['year']

# %%
df['max_power']=df['max_power'].str.replace('bhp','').astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7901 entries, 0 to 8127
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7901 non-null   object
#  1   year           7901 non-null   int64
#  2   selling_price  7901 non-null   int64
#  3   km_driven      7901 non-null   int64
#  4   fuel           7901 non-null   object
#  5   seller_type    7901 non-null   object
#  6   transmission   7901 non-null   object
#  7   owner          7901 non-null   object
#  8   mileage        7901 non-null   float64
#  9   engine         7901 non-null   int32
#  10  max_power      7901 non-null   float64
#  11  torque         7901 non-null   object
#  12  seats          7901 non-null   int32
#  13  no_years       7901 non-null   int64
# dtypes: float64(2), int32(2), int64(4), object(6)
# memory usage: 935.0+ KB

# %%
df.drop('torque',axis=1,inplace=True)

# %%
df.drop('year',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7901 entries, 0 to 8127
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7901 non-null   object
#  1   selling_price  7901 non-null   int64
#  2   km_driven      7901 non-null   int64
#  3   fuel           7901 non-null   object
#  4   seller_type    7901 non-null   object
#  5   transmission   7901 non-null   object
#  6   owner          7901 non-null   object
#  7   mileage        7901 non-null   float64
#  8   engine         7901 non-null   int32
#  9   max_power      7901 non-null   float64
#  10  seats          7901 non-null   int32
#  11  no_years       7901 non-null   int64
# dtypes: float64(2), int32(2), int64(3), object(5)
# memory usage: 842.4+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7901 entries, 0 to 8127
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7901 non-null   object
#  1   selling_price  7901 non-null   int64
#  2   km_driven      7901 non-null   int64
#  3   fuel           7901 non-null   object
#  4   seller_type    7901 non-null   object
#  5   transmission   7901 non-null   object
#  6   owner          7901 non-null   object
#  7   mileage        7901 non-null   float64
#  8   engine         7901 non-null   int32
#  9   max_power      7901 non-null   float64
#  10  seats          7901 non-null   int32
#  11  no_years       7901 non-null   int64
# dtypes: float64(2), int32(2), int64(3), object(5)
# memory usage: 842.4+ KB

# %%
df['company'] = df['name'].str.split(expand=True)[0].astype('str')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7901 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7901 non-null   object
#  1   selling_price  7901 non-null   int64
#  2   km_driven      7901 non-null   int64
#  3   fuel           7901 non-null   object
#  4   seller_type    7901 non-null   object
#  5   transmission   7901 non-null   object
#  6   owner          7901 non-null   object
#  7   mileage        7901 non-null   float64
#  8   engine         7901 non-null   int32
#  9   max_power      7901 non-null   float64
#  10  seats          7901 non-null   int32
#  11  no_years       7901 non-null   int64
#  12  company        7901 non-null   object
# dtypes: float64(2), int32(2), int64(3), object(6)
# memory usage: 873.3+ KB

# %%
df['name'].str.split(expand=True)[0].unique()
# Out:
# array(['Maruti', 'Skoda', 'Honda', 'Hyundai', 'Toyota', 'Ford', 'Renault',
#        'Mahindra', 'Tata', 'Chevrolet', 'Datsun', 'Jeep', 'Mercedes-Benz',
#        'Mitsubishi', 'Audi', 'Volkswagen', 'BMW', 'Nissan', 'Lexus',
#        'Jaguar', 'Land', 'MG', 'Volvo', 'Daewoo', 'Kia', 'Fiat', 'Force',
#        'Ambassador', 'Ashok', 'Isuzu', 'Opel'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7901 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7901 non-null   object
#  1   selling_price  7901 non-null   int64
#  2   km_driven      7901 non-null   int64
#  3   fuel           7901 non-null   object
#  4   seller_type    7901 non-null   object
#  5   transmission   7901 non-null   object
#  6   owner          7901 non-null   object
#  7   mileage        7901 non-null   float64
#  8   engine         7901 non-null   int32
#  9   max_power      7901 non-null   float64
#  10  seats          7901 non-null   int32
#  11  no_years       7901 non-null   int64
#  12  company        7901 non-null   object
# dtypes: float64(2), int32(2), int64(3), object(6)
# memory usage: 873.3+ KB

# %%
df.loc[df['company'] == 'Ashok','company'] = 'Ashok Leyland'

# %%
df.loc[df['company'] == 'Ashok Leyland']
# Out:
#                         name  selling_price  km_driven    fuel seller_type  \
# 4011  Ashok Leyland Stile LE         300000     200000  Diesel  Individual
#
#      transmission         owner  mileage  engine  max_power  seats  no_years  \
# 4011       Manual  Second Owner    20.07    1461       75.0      8         8
#
#             company
# 4011  Ashok Leyland

# %%
df.loc[df['company'] == 'Land','company'] = 'Land Rover'

# %%
df.loc[df['company'] == 'Land Rover']
# Out:
#       selling_price  km_driven    fuel seller_type transmission        owner  \
# 135            45.0     2.1000  Diesel      Dealer    Automatic  First Owner
# 2137           16.5     6.4788  Diesel      Dealer    Automatic  First Owner
# 3240           45.0     2.1000  Diesel      Dealer    Automatic  First Owner
# 5257           45.0     2.1000  Diesel      Dealer    Automatic  First Owner
# 6724           20.0     7.7500  Diesel  Individual    Automatic  Third Owner
# 7711           45.0     2.1000  Diesel      Dealer    Automatic  First Owner
#
#       mileage  engine  max_power  seats  no_years     company
# 135     12.83    1999     148.31      7         2  Land Rover
# 2137     0.00    2179     115.00      5         8  Land Rover
# 3240    12.83    1999     148.31      7         2  Land Rover
# 5257    12.83    1999     148.31      7         2  Land Rover
# 6724    12.70    2179     187.70      5         8  Land Rover
# 7711    12.83    1999     148.31      7         2  Land Rover

# %%
df.loc[4011,'company' ]
# Out:
# 'Ashok Leyland'

# %%
df.drop('name',axis=1,inplace=True)

# %%
df.head()
# Out:
#    selling_price  km_driven    fuel seller_type transmission         owner  \
# 0         450000     145500  Diesel  Individual       Manual   First Owner
# 1         370000     120000  Diesel  Individual       Manual  Second Owner
# 2         158000     140000  Petrol  Individual       Manual   Third Owner
# 3         225000     127000  Diesel  Individual       Manual   First Owner
# 4         130000     120000  Petrol  Individual       Manual   First Owner
#
#    mileage  engine  max_power  seats  no_years  company
# 0    23.40    1248      74.00      5         7   Maruti
# 1    21.14    1498     103.52      5         7    Skoda
# 2    17.70    1497      78.00      5        15    Honda
# 3    23.00    1396      90.00      5        11  Hyundai
# 4    16.10    1298      88.20      5        14   Maruti

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7901 entries, 0 to 8127
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   selling_price  7901 non-null   int64
#  1   km_driven      7901 non-null   int64
#  2   fuel           7901 non-null   object
#  3   seller_type    7901 non-null   object
#  4   transmission   7901 non-null   object
#  5   owner          7901 non-null   object
#  6   mileage        7901 non-null   float64
#  7   engine         7901 non-null   int32
#  8   max_power      7901 non-null   float64
#  9   seats          7901 non-null   int32
#  10  no_years       7901 non-null   int64
#  11  company        7901 non-null   object
# dtypes: float64(2), int32(2), int64(3), object(5)
# memory usage: 842.4+ KB

# %%
plt.figure(figsize=(25,6)) 

sns.countplot(data=df,x='company')

# %%
df.columns
# Out:
# Index(['selling_price', 'km_driven', 'fuel', 'seller_type', 'transmission',
#        'owner', 'mileage', 'engine', 'max_power', 'seats', 'no_years',
#        'company'],
#       dtype='object')

# %%
feat_val =['selling_price', 'km_driven', 'engine', 'max_power', 'no_years']

# %%
for i in range(len(feat_val)) :
    plt.figure(figsize=(25,6)) 
    plt.subplot(5,1,i+1)
    sns.boxplot(x=feat_val[i],data=df)
    plt.show()
    i += 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7901 entries, 0 to 8127
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   selling_price  7901 non-null   int64
#  1   km_driven      7901 non-null   int64
#  2   fuel           7901 non-null   object
#  3   seller_type    7901 non-null   object
#  4   transmission   7901 non-null   object
#  5   owner          7901 non-null   object
#  6   mileage        7901 non-null   float64
#  7   engine         7901 non-null   int32
#  8   max_power      7901 non-null   float64
#  9   seats          7901 non-null   int32
#  10  no_years       7901 non-null   int64
#  11  company        7901 non-null   object
# dtypes: float64(2), int32(2), int64(3), object(5)
# memory usage: 842.4+ KB

# %%
df.head()
# Out:
#    selling_price  km_driven    fuel seller_type transmission         owner  \
# 0         450000     145500  Diesel  Individual       Manual   First Owner
# 1         370000     120000  Diesel  Individual       Manual  Second Owner
# 2         158000     140000  Petrol  Individual       Manual   Third Owner
# 3         225000     127000  Diesel  Individual       Manual   First Owner
# 4         130000     120000  Petrol  Individual       Manual   First Owner
#
#    mileage  engine  max_power  seats  no_years  company
# 0    23.40    1248      74.00      5         7   Maruti
# 1    21.14    1498     103.52      5         7    Skoda
# 2    17.70    1497      78.00      5        15    Honda
# 3    23.00    1396      90.00      5        11  Hyundai
# 4    16.10    1298      88.20      5        14   Maruti

# %%
df['selling_price'] = df['selling_price']/100000
df['km_driven'] = df['km_driven']/10000

# %%
df.groupby('company')['km_driven'].mean()
# Out:
# company
# Ambassador        8.250000
# Ashok Leyland    20.000000
# Audi              5.710708
# BMW               2.996047
# Chevrolet         7.978537
# Daewoo            8.131700
# Datsun            3.634286
# Fiat              8.315605
# Force             5.554650
# Ford              7.246946
# Honda             6.001950
# Hyundai           6.381215
# Isuzu             4.556000
# Jaguar            3.014789
# Jeep              3.713300
# Kia               1.000000
# Land Rover        3.771467
# Lexus             2.000000
# MG                1.236667
# Mahindra          9.067450
# Maruti            6.356798
# Mercedes-Benz     5.216261
# Mitsubishi       14.046364
# Nissan            7.239148
# Opel             11.000000
# Renault           5.905596
# Skoda             7.108614
# Tata              8.068778
# Toyota           10.101644
# Volkswagen        7.231070
# Volvo             1.417164
# Name: km_driven, dtype: float64

# %%
cost_order = df.groupby('company')['selling_price'].mean().sort_values(ascending=False).index.values

# %%
plt.figure(figsize=(10,25)) 
sns.boxplot(y='company',x='selling_price',data=df,order=cost_order)

# %%
plt.figure(figsize=(25,6)) 
sns.countplot(data=df,x='company',order=cost_order)

# %%
df.columns
# Out:
# Index(['selling_price', 'km_driven', 'fuel', 'seller_type', 'transmission',
#        'owner', 'mileage', 'engine', 'max_power', 'seats', 'no_years',
#        'company'],
#       dtype='object')

# %%
plx.box(y=df['fuel'],x=df['selling_price'])
# Out:
# <div>
#
#
#             <div id="8a3928a6-3fda-4a14-ae5e-571ca0243a35" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8a3928a6-3fda-4a14-ae5e-571ca0243a35")) {
#                     Plotly.newPlot(
#                         '8a3928a6-3fda-4a14-ae5e-571ca0243a35',
#                         [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "h", "showlegend": false, "type": "box", "x": [4.5, 3.7, 1.58, 2.25, 1.3, 4.4, 0.96, 0.45, 3.5, 2.0, 5.0, 0.92, 2.8, 1.8, 4.0, 7.78, 5.0, 1.5, 6.8, 1.74, 9.5, 5.25, 6.0, 5.0, 5.75, 2.75, 3.0, 2.2, 2.54999, 6.7, 1.5, 7.3, 6.5, 3.3, 3.66, 11.49, 1.5, 4.25, 1.5, 21.0, 9.25, 4.25, 6.75, 8.19999, 3.9, 15.0, 7.0, 14.5, 4.25, 10.9, 6.0, 8.5, 5.25, 16.5, 9.5, 17.5, 15.9, 16.89999, 14.25, 2.65, 1.9, 4.25, 6.3, 6.0, 6.5, 5.4, 6.3, 4.
# %%
sns.heatmap(df.corr(),
           annot=True,
           cmap='RdBu')

# %%
plx.histogram(df,x='selling_price',
             nbins=50,
             color='fuel')
# Out:
# <div>
#
#
#             <div id="04d47d7c-3401-49b3-a1ec-7aff605b05f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("04d47d7c-3401-49b3-a1ec-7aff605b05f7")) {
#                     Plotly.newPlot(
#                         '04d47d7c-3401-49b3-a1ec-7aff605b05f7',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "fuel=Diesel<br>selling_price=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "Diesel", "marker": {"color": "#636efa"}, "name": "Diesel", "nbinsx": 50, "offsetgroup": "Diesel", "orientation": "v", "showlegend": true, "type": "histogram", "x": [4.5, 3.7, 2.25, 3.5, 2.0, 5.0, 2.8, 7.78, 5.0, 6.8, 1.74, 9.5, 5.25, 6.0, 3.0, 6.7, 6.5, 4.25, 8.19999, 15.0, 7.0, 14.5, 4.25, 10.9, 6.0, 5.25, 16.5, 9.5, 17.5, 16.89999, 14.25, 2.65, 4.25, 6.3, 5.4, 6.3, 5.0, 7.45, 10.25, 6.3, 17.0, 4.5, 4.5, 12.0, 6.1, 6.0, 7.25, 2.0, 6.25, 17.0, 3.75, 5.22, 4.51999, 7.8, 4.0, 11.4, 8.5, 3.7, 6.25, 7.0, 39.75, 32.0, 45.0, 60.0, 37.9, 58.0, 27.0, 34.0, 26.5, 5.35, 58.5, 26.25, 15.25, 10.25, 21.5, 29.0, 3.0, 1.6, 2.2, 3.0, 17.5, 4.9, 8.0, 5.8, 12.5, 7.0, 8.0, 7.75, 9.0, 3.0, 2.5, 11.0, 6.4, 6.5, 5.35, 7.0, 5.5, 5.0, 10.0, 1.7, 8.0, 5.0, 13.8, 13.0, 5.3, 3.6, 3.1, 7.25, 3.4, 5.5, 11.5, 3.8, 4.8, 7.8, 3.2, 5.0, 4.04, 5.0, 3.5, 2.9, 4.5, 4.0, 2.1, 46.0, 5.09999, 6.5, 3.95, 13.0, 12.5, 5.55, 8.0, 12.1, 5.2, 4.04, 1.85, 2.5, 2.65, 4.8, 1.7, 2.75, 1.7, 11.0, 30.0, 4.0, 5.7, 6.8, 3.25, 15.5, 2.5, 5.5, 26.25, 32.0, 5.03, 38.0, 7.4, 7.5, 4.5, 54.0, 55.0, 24.75, 4.8, 5.35, 2.5, 3.0, 3.4, 7.5, 0.95, 12.9, 26.25, 32.0, 5.03, 38.0, 7.4, 7.5, 4.5, 54.0, 55.0, 24.75, 7.0, 9.5, 4.09999, 8.4, 4.5, 9.0, 5.7, 2.54999, 5.3, 5.2, 2.29999, 6.0, 2.92, 3.9, 15.25, 9.5, 6.1, 5.25, 7.0, 3.75, 5.8, 7.3, 10.5, 7.35, 10.5, 4.2, 8.0, 20.0, 6.0, 19.0, 5.0, 2.0, 2.6, 2.8, 3.0, 1.4, 5.6, 7.5, 5.85, 4.3, 4.8, 6.43, 2.85, 2.5, 4.09999, 7.0, 3.0, 2.2, 2.5, 0.88, 5.61, 7.55, 1.9, 1.1, 3.2, 16.0, 
, 26.25, 32.0, 5.03, 38.0, 7.4, 7.5, 4.5, 54.0, 55.0, 24.75, 26.25, 32.0, 5.03, 38.0, 7.4, 7.5, 4.5, 54.0, 55.0, 24.75, 26.25, 32.0, 5.03, 38.0, 7.4, 7.5, 4.5, 54.0, 55.0, 24.75, 3.85, 5.5, 2.7, 2.0, 7.0, 4.8, 3.5, 6.0, 3.5, 7.7, 3.5, 6.0, 7.5, 2.54999, 1.0, 5.75, 7.8, 4.67, 10.5, 2.6, 2.8, 3.5, 2.29999, 5.5, 8.5, 3.7, 6.5, 5.3, 2.65, 4.3, 7.11, 4.5, 4.34999, 2.1, 11.0, 6.0, 7.5, 1.9, 3.51, 10.0, 0.55, 2.0, 5.0, 8.33, 2.8, 1.8, 14.0, 3.4, 5.5, 6.5, 7.3, 8.8, 4.8, 8.5, 3.0, 3.0, 4.5, 4.0, 10.3, 1.9, 8.0, 2.29999, 3.0, 3.75, 4.2, 3.0, 1.5, 6.0, 2.04999, 6.25, 2.8, 10.5, 5.35, 5.09999, 5.21, 5.11, 4.51, 4.5, 2.5, 2.0, 9.5, 4.0, 5.09999 ...

# %%
plx.histogram(df,x='owner')
# Out:
# <div>
#
#
#             <div id="092c095a-4d23-4855-87e3-840a1ecec0a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("092c095a-4d23-4855-87e3-840a1ecec0a6")) {
#                     Plotly.newPlot(
#                         '092c095a-4d23-4855-87e3-840a1ecec0a6',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "owner=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": ["First Owner", "Second Owner", "Third Owner", "First Owner", "First Owner", "First Owner", "First Owner", "Second Owner", "First Owner", "First Owner", "Second Owner", "Second Owner", "Second Owner", "Second Owner", "First Owner", "Second Owner", "Second Owner", "Second Owner", "First Owner", "Second Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "Second Owner", "First Owner", "First Owner", "Second Owner", "First Owner", "First Owner", "First Owner", "Second Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "Second Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "Second Owner", "First Owner", "Second Owner", "First Owner", "First Owner", "First Owner", "First Owner", "Third Owner", "First Owner", "Second Owner", "Third Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "Second Owner", "First Owner", "Second Owner", "Second Owner", "Second Owner", "First Owner", "First Owner", "First Owner", "Second Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "Second Owner", "Second Owner", "First Owner", "First Owner", "First Owner", "First Owner", "Third Owner", "First Owner", "Second Owner", "Second Owner", "First Owner", "Third Owner", "First Owner", "Second Owner", "Second Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "Second Owner", "First Owner", "Second Owner", "First Owner", "First Owner", "First Owner", "First Owner", "Third Owner", "First Owner", "First Owner", "Fourth & Above Owner", "First Owner", "Second Owner", "Fourth & Above Owner", "Second Owner", "Second Owner", "Second Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "Second Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "Second Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "Second Owner", "First Owner", "First Owner", "First Owner", "Second Owner", "Second Owner", "Second Owner", "First Owner", "First Owner", "First Owner", "Second Owner", "First Owner", "Second Owner", "Second Owner", "First Owner", "First Owner", "Second Owner", "Second Owner", "First Owner", "Second Owner", "First Owner", "Second Owner", "Third Owner", "Second Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "Second Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "Second Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "Second Owner", "First Owner", "Second Owner", "First Owner", "First Owner", "First Owner", "Second Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "Second Owner", "Second Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "First Owner", "Second Owner", "First Owner", "First Owner", "First Owner", "First Owner", "Second Owner", "Second Owner", "First Owner", "Second Owner", "Second Owner" ...

# %%
feat_1 = [ 'Year','Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']

# %%
for i in range(len(feat_1)) :
    plt.figure(figsize=[10,4])
    plt.figure()
    sns.countplot(x=feat_1[i],data=df_1)
    plt.show()
    i += 1

# %%
df_1 = pd.read_csv('car data.csv')

# %%
df_1.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df_1.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# no_years           int64
# dtype: object

# %%
df_1.shape
# Out:
# (301, 9)

# %%
print(df_1['Fuel_Type'].unique())
print(df_1['Seller_Type'].unique())
print(df_1['Transmission'].unique())
print(df_1['Owner'].unique())
# Out:
# ['Petrol' 'Diesel' 'CNG']
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
df_1.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df_1.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df_1['no_years'] = 2020

# %%
df_1.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  no_years
# 0      Dealer       Manual      0      2020
# 1      Dealer       Manual      0      2020
# 2      Dealer       Manual      0      2020
# 3      Dealer       Manual      0      2020
# 4      Dealer       Manual      0      2020
